# %%
while True:
    flag = True
    word = input().upper()
    if word and len(word) < 1000000:
        for letter in word:
            try:
                int(letter)
                flag = False
                break 
            except:
                pass
        
        if flag:
            break

if len(word) == 1:
    print(word)

count_dict = {letter: word.count(letter) for letter in set(word)}

if sorted(list(count_dict.values()))[-1] == sorted(list(count_dict.values()))[-2]:
    print("?")
else:
    for key, value in count_dict.items():
        if value == sorted(list(count_dict.values()))[-1]:
            print(key)
# Out:
# ?

# %%
word_set = {word}

count_dict = {letter: word.count(letter) for letter in word}

if sorted(list(count_dict.values()))[-1] == sorted(list(count_dict.values()))[-2]:
    print("?")
else:
    for key, value in count_dict.items():
        if value == sorted(list(count_dict.values()))[-1]:
            print(key)
# Out:
# Z
