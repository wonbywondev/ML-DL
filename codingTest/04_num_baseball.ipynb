# %%
def solution(n, submit):
    global count, count_dict, prev_S, prev_B

    prev_S = 0
    prev_B = 0
    
    exact_count = 0
    count = 0
    
    candidate_dict = {
        0: {str(i) for i in range(1, 10)},
        1: {str(i) for i in range(0, 10)},
        2: {str(i) for i in range(0, 10)},
        3: {str(i) for i in range(0, 10)}
        }
    
    def consider(i):
        str_i = str(i)
        possible = True

        for idx, each_num in enumerate(str_i):
            if each_num not in candidate_dict[idx]:
                possible = False
                break

        if possible:
            print(i, True)
            return True
        

    for i in range(1000, 10000):
        if consider(i):
            submit(i)
            count += 1

            if submit(i) == "4S 0B": 
                return i
            else:
                now_i = str(i)
                now_S = int(submit(i)[0])
                now_B = int(submit(i)[3])

                if now_S + now_B == 0:
                    for set_ in candidate_dict.values():
                        set_ = set_ - set(now_i)

                if now_S + now_B == 4:
                    for idx in range(0,4):
                        candidate_dict[idx] = set(candidate_dict[idx]) & set([num for num in now_i if num != now_i[idx]])
                        
                if count == 1:
                    prev_i = now_i
                    prev_S = now_S
                    prev_B = now_B
                    continue

                same_index = [idx for idx in range(0,4) if now_i[idx] == prev_i[idx]]
                diff_index = [idx for idx in range(0,4) if now_i[idx] != prev_i[idx]]
                diff_count = len(diff_index)

    return 0

# %%
a = "4s 1b"

print(a[1])
# Out:
# {1, 4}
